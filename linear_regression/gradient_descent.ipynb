# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20)

# %%
plt.scatter(x,y)

# %% [markdown]
# ## appyling linear regresion and checking the results first

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [85.3863503]
# 1.7429274025447867

# %% [markdown]
# # so here the slope (m)=85.38<br>
# # and intercept(b)=1.74

# %%
m=85.38

# %%
class gdregressor:
    def __init__(self,learning_rate,epochs):
        self.m=85.38
        self.b=50
        self.lr=learning_rate
        self.epochs=epochs
    
    def fit(self,x,y):
        #calculate the b using gradient descent
        for i in range(self.epochs):
            loss_slope= -2 * np.sum(y - self.m*x.ravel() - self.b)
            self.b=self.b - (self.lr * loss_slope)#upading the value of b because we are comsidering random values for b
            print(loss_slope,self.b)
        print(self.b)

# %%
gd=gdregressor(0.001,100)

# %%
gd.fit(x,y)
# Out:
# 9651.34252759108 40.34865747240892
# 7721.074022072861 32.627583450336054
# 6176.85921765829 26.450724232677764
# 4941.487374126632 21.509236858551134
# 3953.1898993013056 17.556046959249827
# 3162.551919441044 14.393495039808784
# 2530.0415355528344 11.863453504255949
# 2024.0332284422684 9.83942027581368
# 1619.2265827538145 8.220193693059866
# 1295.3812662030514 6.924812426856814
# 1036.3050129624412 5.888507413894373
# 829.0440103699531 5.059463403524419
# 663.235208295962 4.396228195228457
# 530.5881666367699 3.865640028591687
# 424.4705333094159 3.441169495282271
# 339.57642664753274 3.101593068634738
# 271.6611413180261 2.829931927316712
# 217.32891305442098 2.612603014262291
# 173.86313044353653 2.438739883818754
# 139.0905043548292 2.299649379463925
# 111.27240348386329 2.1883769759800615
# 89.01792278709082 2.0993590531929707
# 71.21433822967236 2.0281447149632985
# 56.97147058373791 1.9711732443795607
# 45.5771764669907 1.9255960679125699
# ...

# %%
actual_b=1.7429274025447867
predicted_b_gd=1.7432873718746742

# %% [markdown]
# so if the above value is not coming to the actual we have to change the learning rate and aslo still not then change the epochs

# %%
 # loss_slope= -2 * np.sum(y - self.m*x.ravel() - self.b)
#this is the derivative of loss function w.r.t.b
# loss function =tell how good/bad is your model
# derivastive=tells how to imporve the model 
## loss slope=gradient
